# %%
# Salary Prediction

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error

data=pd.read_csv("Salary.csv")
data=data.dropna()

x=data.drop(columns=("Salary"))
x=pd.get_dummies(x)

y=data["Salary"]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

model=LinearRegression()

Training=model.fit(x_train,y_train)

Predicting=model.predict(x_test)

print(pd.DataFrame({
    "Actual Values": y_test[:10],
    "Predicted Values": Predicting[:10]
}))

plt.title("Salary Prediction")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.plot(y_test[:10],color="green",marker="x",label="Actual")
plt.plot(Predicting[:10],color="red",marker="x",label="Predicted")
plt.legend()
plt.show()


index = np.arange(len(y_test[:10]))  # same x positions for both

plt.scatter(index, y_test[:10], color="blue", label="Actual Salary", marker="o")
plt.scatter(index, Predicting[:10], color="green", label="Predicted Salary", marker="x")
plt.title("Actual vs Predicted Salary")
plt.xlabel("Sample")
plt.ylabel("Salary")
plt.legend()
plt.grid(True)
plt.show()


print("R2 Score:", r2_score(y_test, Predicting))
print("MSE:", mean_squared_error(y_test, Predicting))
